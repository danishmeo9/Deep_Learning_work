# %% [markdown]
# # **BASIC TEXT CLASSIFICATION**

# %%
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import losses

# %% [markdown]
# ## Sentiment analysis
#
# This notebook trains a sentiment analysis model to classify movie reviews as *positive* or *negative*, based on the text of the review. This is an example of *binary*—or two-class—classification, an important and widely applicable kind of machine learning problem.
#
# You'll use the [Large Movie Review Dataset](https://ai.stanford.edu/~amaas/data/sentiment/) that contains the text of 50,000 movie reviews from the [Internet Movie Database](https://www.imdb.com/). These are split into 25,000 reviews for training and 25,000 reviews for testing. The training and testing sets are *balanced*, meaning they contain an equal number of positive and negative reviews.

# %%
# Load data set
# download and upload the dataset from the given URL
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file("aclImdb_v1", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\file_utils.py:117, in extract_archive(file_path, path, archive_format)
#     115     else:
#     116         # Tar archive, perhaps unsafe. Filter paths.
# --> 117         archive.extractall(
#     118             path, members=filter_safe_paths(archive)
#     119         )
#     120 except (tarfile.TarError, RuntimeError, KeyboardInterrupt):
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2302, in TarFile.extractall(self, path, members, numeric_owner, filter)
#    2301         directories.append(tarinfo)
# -> 2302     self._extract_one(tarinfo, path, set_attrs=not tarinfo.isdir(),
#    2303                       numeric_owner=numeric_owner)
#    2305 # Reverse sort directories.
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2365, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2364 try:
# -> 2365     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2366                          set_attrs=set_attrs,
#    2367                          numeric_owner=numeric_owner)
#    2368 except OSError as e:
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2448, in TarFile._extract_member(self, tarinfo, targetpath, set_attrs, numeric_owner)
#    2447 if tarinfo.isreg():
# -> 2448     self.makefile(tarinfo, targetpath)
#    2449 elif tarinfo.isdir():
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2494, in TarFile.makefile(self, tarinfo, targetpath)
#    2493 bufsize = self.copybufsize
# -> 2494 with bltn_open(targetpath, "wb") as target:
#    2495     if tarinfo.sparse is not None:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 5
#       1 # Load data set
#       2 # download and upload the dataset from the given URL
#       3 url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
# ----> 5 dataset = tf.keras.utils.get_file("aclImdb_v1", url,
#       6                                     untar=True, cache_dir='.',
#       7                                     cache_subdir='')
#       9 dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\file_utils.py:339, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     336 if untar:
#     337     archive_format = "tar"
# --> 339 status = extract_archive(
#     340     download_target, extraction_dir, archive_format
#     341 )
#     342 if not status:
#     343     warnings.warn("Could not extract archive.", stacklevel=2)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\file_utils.py:125, in extract_archive(file_path, path, archive_format)
#     123                 os.remove(path)
#     124             else:
# --> 125                 shutil.rmtree(path)
#     126         raise
#     127 return True
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\shutil.py:781, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     779     # can't continue even if onexc hook returns
#     780     return
# --> 781 return _rmtree_unsafe(path, onexc)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\shutil.py:635, in _rmtree_unsafe(path, onexc)
#     633             os.unlink(fullname)
#     634         except OSError as err:
# --> 635             onexc(os.unlink, fullname, err)
#     636 try:
#     637     os.rmdir(path)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\shutil.py:633, in _rmtree_unsafe(path, onexc)
#     631 fullname = os.path.join(dirpath, name)
#     632 try:
# --> 633     os.unlink(fullname)
#     634 except OSError as err:
#     635     onexc(os.unlink, fullname, err)
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: '.\\aclImdb_v1\\aclImdb\\test\\neg\\4219_1.txt'

# %%
os.listdir(dataset_dir)

# %%
 train_dir = os.path.join(dataset_dir, 'train')
